# %% [markdown]
# # Deep learning rizz

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Defining variables
# Certain variables, like the number of nodes, the input and output data, assigning weights, can then instantiate the model.

# %% [markdown]
# ### Defining the number of nodes
# However, for simplicity, the number of nodes is only 2, so it is a very limited model.

# %%
i_nodes = 2
o_nodes = 2
h_nodes = 3
batch_size = 8

# %% [markdown]
# ### Defining the input data and output data
# They are generated from the standard normal distribution curve.

# %%
i_data = np.random.randn(batch_size, i_nodes)
o_data = np.random.randn(batch_size, o_nodes)

print("Input data:", i_data)
print("Output data:", o_data)
# Out:
# Input data: [[-0.31762138 -1.17183973]
#  [ 0.03926414 -1.4251897 ]
#  [-0.76381646  1.52987565]
#  [-0.5647861   0.07305078]
#  [-0.91184548 -0.37399321]
#  [-1.27733032 -2.18319284]
#  [-4.0792657  -0.37326382]
#  [-0.56344987  0.16791373]]
# Output data: [[-0.36059696  0.55292124]
#  [-0.16280221 -1.1316926 ]
#  [-2.05724115 -0.15051097]
#  [-0.44991363  0.99072083]
#  [ 0.06595375 -0.76437781]
#  [ 0.62362521  1.34294314]
#  [-0.33526059  0.67940387]
#  [ 0.2250639  -0.49723525]]

# %% [markdown]
# ### Assigning random weights to the model
# Where:
# - $w_{1}$ is the synapses between input node and hidden nodes, and
# - $w_{2}$ is the synapses between the hidden node and output node.

# %%
w1 = np.random.randn(i_nodes, h_nodes)
w2 = np.random.randn(h_nodes, o_nodes)

# %% [markdown]
# ### Loss arrays as empty arrays

# %%
loss_array = np.array([[]])
indices = np.array([[]])

# %% [markdown]
# ### Training the model iteratively
# The epochs, ie the number of times the model is trained, is defined by the number of times the for loop loops.

# %% [markdown]
# ### Obtaining hidden values

# %% [markdown]
# if input data, $ i = \begin{bmatrix} a_{1} & a_{2} \\ a_{3} &  a_{4} \\ a_{5} & a_{6} \\ a_{7} & a_{8} \\ a_{9} & a_{10} \\ a_{11} &  a_{12} \\ a_{13} & a_{14} \\ a_{15} & a_{16} \end{bmatrix}, $
# and
# $ w_{1} = \begin{bmatrix} b_{1} & b_{2} & b_{3} \\ b_{4} & b_{5} & b_{6}  \end{bmatrix}, $
#
# hence, hidden values, $ h_{values} = i \cdot w_{1} $
# $ = \begin{bmatrix}a_{1} & a_{2} \\ a_{3} &  a_{4} \\ a_{5} & a_{6} \\ a_{7} & a_{8} \\ a_{9} & a_{10} \\ a_{11} &  a_{12} \\ a_{13} & a_{14} \\ a_{15} & a_{16}  \end{bmatrix} \cdot
#  \begin{bmatrix} b_{1} & b_{2} & b_{3} \\ b_{4} & b_{5} & b_{6}  \end{bmatrix} $

# %%
h_values = i_data.dot(w1)

# %% [markdown]
# ### Activation function for hidden layer - ReLU
# The formula for ReLU is:
# $\begin{align*} f(x) = max(x, 0)\end{align*} $
#
# where $x$ is the value in that node in the hidden layer. It replaces negative values with 0, and stores it into the variable, $h_{ReLU}$

# %%
h_relu = np.maximum(h_values, 0)

# %% [markdown]
# ### Calculating predictions
# Then, it multiplies the values obtained from the hidden layers, $h_{ReLU}$, into the matrix of the second weight.

# %%
print("Shape of hidden ReLU matrix:", h_relu.shape)
print("Shape of w2 matrix:", w2.shape)
# Out:
# Shape of hidden ReLU matrix: (8, 3)
# Shape of w2 matrix: (3, 2)

# %% [markdown]
# if hidden ReLU, $ h_{ReLU} =
# \begin{bmatrix}
# a_{1} & a_{2} & a_{3} \\
# a_{4} &  a_{5} & a_{6} \\
# a_{7} & a_{8} & a_{9} \\
# a_{10} & a_{11} & a_{12} \\
# a_{13} &  a_{14} & a_{15} \\
# a_{16} & a_{17} & a_{18}
# \end{bmatrix}, $
#
# and $ w_{2} =
# \begin{bmatrix}
# b_{1} & b_{2} \\
# b_{3} & b_{4} \\
# b_{3} & b_{4} \end{bmatrix}, $
#
# hence, output data predictions, $ output_{pred} = h_{ReLU} \cdot w_{2}
# = \begin{bmatrix}
# a_{1} & a_{2} & a_{3} \\
# a_{4} & a_{5} & a_{6} \\
# a_{7} & a_{8} & a_{9} \\
# a_{10} & a_{11} & a_{12} \\
# a_{13} & a_{14} & a_{15} \\
# a_{16} & a_{17} & a_{18}
# \end{bmatrix} \cdot
# \begin{bmatrix}
# b_{1} & b_{2} \\
# b_{3} & b_{4} \\
# b_{3} & b_{4} \end{bmatrix} $

# %%
o_data_predictions = h_relu.dot(w2)

# %% [markdown]
# ### Loss function
# The Mean Squared Error (MSE) is calculated as:
#
# $ mse = \frac{1}{N} \sum_{i=1}^{N}(y_i - \hat{y}_i)^2$
#
# Where:
# - $N$ is the total number of data points.
# - $y_{i}$ represents the actual values.
# - $\hat{y}_i$ represents the predicted values.
#
# Each iteration of finding the loss is appended into the loss array, shown later.

# %%
loss = np.square(o_data_predictions-o_data).sum()

# %% [markdown]
# Now, we let $a$ = $y_{i}$, and $y$ = $\hat{y}_i$. Then, let each loss be $C = (a - y)^{2}$. This is known as a loss function.
#
# Gradient Descent, refers to descending along the loss function, in the direction of the slope of C.
#
# Gradient of Prediction = $\frac{δC}{δa} = 2(a-y)$

# %%
grad_pred = 2 * (o_data_predictions - o_data)

# %% [markdown]
# How about relative to $w_{2}$?
# Given that the chain rule for differentiation is $\frac{δ}{δx}fg(x) = g'(x) \cdot f'(g(x))$.
#
# Then

# %%
grad_w2 = h_relu.T.dot(grad_pred)

# %%
for i in range(70000):
    h_values = i_data.dot(w1)
    h_relu = np.maximum(h_values, 0)
    o_data_predictions = h_relu.dot(w2)

    loss = np.square(o_data_predictions-o_data).sum()
    loss_array = np.append(loss_array, loss)
    indices = np.append(indices, i)
    grad_pred = 2 * (o_data_predictions - o_data)

    grad_w2 = h_relu.T.dot(grad_pred)
    grad_h_relu = grad_pred.dot(w2.T)

    grad_h_values = grad_h_relu.copy()
    grad_h_values[h_values < 0] = 0

    grad_w1 = i_data.T.dot(grad_h_values)

    w1 = w1 - grad_w1 * 1e-4
    w2 = w2 - grad_w2 * 1e-4

plt.plot(indices, loss_array)
plt.legend(['Loss over iterations'])
plt.show()

print(o_data)
print(o_data_predictions)
# Out:
# [[-0.36059696  0.55292124]
#  [-0.16280221 -1.1316926 ]
#  [-2.05724115 -0.15051097]
#  [-0.44991363  0.99072083]
#  [ 0.06595375 -0.76437781]
#  [ 0.62362521  1.34294314]
#  [-0.33526059  0.67940387]
#  [ 0.2250639  -0.49723525]]
# [[ 0.09752149  0.18558775]
#  [ 0.15174842  0.11818752]
#  [-2.03180764 -0.1729649 ]
#  [-0.04843944  0.04639606]
#  [-0.03199725  0.26401178]
#  [ 0.12829249  0.51898448]
#  [-0.1650411   0.82854607]
#  [-0.16992134 -0.01445926]]

# %% [markdown]
# ### Assessing the accuracy of the model

# %%
def calculate_accuracy(o_data, o_data_predictions):
    """Calculates the accuracy between the predicted and actual values."""

    diff = o_data_predictions - o_data
    squared_diff = np.square(diff)
    sum_squared_diff = squared_diff.sum()
    n = o_data.shape[0]
    rmse = np.sqrt(sum_squared_diff / n)
    return 1 - rmse

accuracy = calculate_accuracy(o_data, o_data_predictions)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.1714638942686213

# %% [markdown]
# ### Rectified Linear Unit (ReLU)
# Removes all negative values, replace them with 0

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

x = np.arange(-8, 8, 0.1)
y = np.arange(-8, 8, 0.1)
x, y = np.meshgrid(x, y)

z = x ** 2 + y ** 2

axes = plt.axes(projection = '3d')
axes.plot_surface(x, y, z)


#derivative = 2 * x
#plt.plot(x, y, x, z)
#plt.show()

# %% [markdown]
# ### Sources:
# - The Absolutely Simplest Neural Network Backpropagation Example: https://www.youtube.com/watch?v=khUVIZ3MON8
# - Coding a Neural Network: A Beginner's Guide (part 1): https://www.youtube.com/watch?v=TIEKzVwS12g&ab_channel=AboutMedicine
